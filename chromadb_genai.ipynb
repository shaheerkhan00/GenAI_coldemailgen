# %%
import chromadb
client = chromadb.Client()
collection=client.create_collection(name="my_collection")
# Out:
# ---------------------------------------------------------------------------
# UniqueConstraintError                     Traceback (most recent call last)
# Cell In[3], line 3
#       1 import chromadb
#       2 client = chromadb.Client()
# ----> 3 collections=client.create_collection(name="my_collection")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\api\client.py:147, in Client.create_collection(self, name, configuration, metadata, embedding_function, data_loader, get_or_create)
#     135 @override
#     136 def create_collection(
#     137     self,
#    (...)
#     145     get_or_create: bool = False,
#     146 ) -> Collection:
# --> 147     model = self._server.create_collection(
#     148         name=name,
#     149         metadata=metadata,
#     150         tenant=self.tenant,
#     151         database=self.database,
#     152         get_or_create=get_or_create,
#     153         configuration=configuration,
#     154     )
#     155     return Collection(
#     156         client=self._server,
#     157         model=model,
#     158         embedding_function=embedding_function,
#     159         data_loader=data_loader,
#     160     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\telemetry\opentelemetry\__init__.py:150, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     148 global tracer, granularity
#     149 if trace_granularity < granularity:
# --> 150     return f(*args, **kwargs)
#     151 if not tracer:
#     152     return f(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\api\segment.py:103, in rate_limit.<locals>.wrapper(*args, **kwargs)
#     100 @wraps(func)
#     101 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     102     self = args[0]
# --> 103     return self._rate_limit_enforcer.rate_limit(func)(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\rate_limit\simple_rate_limit\__init__.py:24, in SimpleRateLimitEnforcer.rate_limit.<locals>.wrapper(*args, **kwargs)
#      22 @wraps(func)
#      23 def wrapper(*args: Any, **kwargs: Any) -> Any:
# ---> 24     return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\api\segment.py:242, in SegmentAPI.create_collection(self, name, configuration, metadata, get_or_create, tenant, database)
#     229 model = CollectionModel(
#     230     id=id,
#     231     name=name,
#    (...)
#     238     dimension=None,
#     239 )
#     241 # TODO: Let sysdb create the collection directly from the model
# --> 242 coll, created = self._sysdb.create_collection(
#     243     id=model.id,
#     244     name=model.name,
#     245     configuration=model.get_configuration(),
#     246     segments=[],  # Passing empty till backend changes are deployed.
#     247     metadata=model.metadata,
#     248     dimension=None,  # This is lazily populated on the first add
#     249     get_or_create=get_or_create,
#     250     tenant=tenant,
#     251     database=database,
#     252 )
#     254 if created:
#     255     segments = self._manager.prepare_segments_for_new_collection(coll)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\telemetry\opentelemetry\__init__.py:150, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     148 global tracer, granularity
#     149 if trace_granularity < granularity:
# --> 150     return f(*args, **kwargs)
#     151 if not tracer:
#     152     return f(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\chromadb\db\mixins\sysdb.py:305, in SqlSysDB.create_collection(self, id, name, configuration, segments, metadata, dimension, get_or_create, tenant, database)
#     298         return (
#     299             self.get_collections(
#     300                 id=collection.id, tenant=tenant, database=database
#     301             )[0],
#     302             False,
#     303         )
#     304     else:
# --> 305         raise UniqueConstraintError(f"Collection {name} already exists")
#     307 collection = Collection(
#     308     id=id,
#     309     name=name,
#    (...)
#     315     version=0,
#     316 )
#     318 with self.tx() as cur:
#
# UniqueConstraintError: Collection my_collection already exists

# %%
collection.add(
    documents=[
        'this document is about New York',
        'this document is about Delhi',
        'This document is about karachi'
    ],
    ids=['id1','id2','id3']
)
# Out:
# C:\Users\SHAHEERk\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██| 79.3M/79.3M [00:01<00:00, 61.0MiB/s]

# %%
all_docs=collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2', 'id3'],
#  'embeddings': None,
#  'documents': ['this document is about New York',
#   'this document is about Delhi',
#   'This document is about karachi'],
#  'uris': None,
#  'data': None,
#  'metadatas': [None, None, None],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
document1=collection.get(ids='id1')
document1
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['this document is about New York'],
#  'uris': None,
#  'data': None,
#  'metadatas': [None],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
results=collection.query(
    query_texts=['Query is about Quaid e Azam Muhammad Ali Jinnah'],
    n_results=2
)
results
# Out:
# {'ids': [['id3', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about karachi',
#    'this document is about Delhi']],
#  'uris': None,
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.1644123792648315, 1.3714714050292969]],
#  'included': [<IncludeEnum.distances: 'distances'>,
#   <IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}
